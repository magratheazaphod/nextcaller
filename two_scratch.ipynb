# %%
import pandas as pd

# %%
accred_df = pd.read_csv('Accreditation_Data.csv')

# %%
accred_df[:100]
# Out:
#                                           Institution  \
# 0                American Commercial College of Texas
# 1               American Commercial College - Abilene
# 2                        Anson College of Cosmetology
# 3              American College of Medical Technology
# 4   Aviation and Electronic Schools of America - C...
# 5              American University of Health Sciences
# 6                          Gerber Akron Beauty School
# 7                           Adult Vocational Services
# 8                Alexandria Academy of Beauty Culture
# 9                         Fortis Institute - Scranton
# 10                  American Beauty Academy - Wheaton
# 11     American College of Hairstyling - Cedar Rapids
# 12                                    Antioch College
# 13                    Antonelli College - Hattiesburg
# 14             Academy of Oriental Medicine at Austin
# 15                    Empire Beauty School - Glendale
# ...
